# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fn = 'LAL-iterativetree-simulated2Gauss2dim.npz'
filename = './lal datasets/'+fn
regression_data = np.load(filename)
regression_features = regression_data['arr_0']
regression_labels1 = regression_data['arr_1']

# %%
print(np.shape(regression_labels1))
# Out:
# (180000,)

# %%
180000/5000
# Out:
# 36.0

# %%
regression_labels1
# Out:
# array([ 0.217  ,  0.02825, -0.53225, ...,  0.0235 ,  0.0285 ,  0.03275])

# %%
plt.plot(regression_labels1, '.')

# %%
fn = 'LAL-iterativetree-simulatedunbalanced-big.npz'
filename = '../17 - generic LAL dataset generation/lal datasets/'+fn
regression_data = np.load(filename)
regression_features = regression_data['arr_0']
regression_labels = regression_data['arr_1']

# %%
regression_labels
# Out:
# array([ 0.217  ,  0.02825, -0.53225, ...,  0.00325,  0.00725,  0.0055 ])

# %%
plt.plot(regression_labels, '.')

# %%
regression_labels.shape
# Out:
# (240000,)

# %%
np.allclose(regression_labels[:10000], regression_labels1[:10000])
# Out:
# True
